# %%
#Shilin and Luis

import pandas as pd

dataset = pd.read_csv('data/gapminder_all.csv', index_col='country')
print(dataset.boxplot(column='gdpPercap_2007'))
print(dataset.boxplot(column='lifeExp_2007',by='continent'))
print(dataset[dataset['continent']=='Americas'].boxplot(column='pop_2007',by='country'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.1,0.15;0.8x0.75)
# AxesSubplot(0.1,0.15;0.8x0.75)
