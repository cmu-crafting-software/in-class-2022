# %%
import csv
import pandas as pd
import matplotlib


csv_input = pd.read_csv("gapminder_all.csv")

# %%
boxplot = csv_input.boxplot("gdpPercap_2007")

# %%
boxplot_lifespan = csv_input.groupby(['continent']).mean().boxplot("lifeExp_2007")
